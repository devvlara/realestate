# %% [markdown]
# Centralize All Data Pertaining to a Zillow House Listing in One Master File

# %% [markdown]
# # Import Packages

# %%
date = '2024-10-09'

# %%
import os
import yaml
import datetime
import pandas as pd
import numpy as np

# Load the configuration file
with open(r'C:/Users/Dev/Documents/Real Estate Data/config/config.yaml', 'r') as file:
    config = yaml.safe_load(file)

# %% [markdown]
# # Directories

# %%
# Imported Data Directory
area_dir = config['data']['simplemaps_data']['master']
listing_dir = config['data']['zillow_data']['processed']['listings']['zillow_search_scraper']
census_dir = config['data']['census_data']['master']

# Cleaned Data Directory
master_dir = config['data']['zillow_data']['master']['listings']['zillow_search_scraper']

# %% [markdown]
# # Files

# %%
# Imported Data 
area = 'simplemaps_master_data.csv'
listings = f'{date}_zillow_house_listings.csv'
census = 'census_master_data.csv'

# Cleaned Data
master_file = f'{date}_zillow_listing_master.csv'

# %% [markdown]
# # Import Files

# %%
file_path = os.path.join(area_dir, area)
area = pd.read_csv(file_path, low_memory=False)

file_path = os.path.join(listing_dir, listings)
listings = pd.read_csv(file_path, low_memory=False)

file_path = os.path.join(census_dir, census)
census = pd.read_csv(file_path, low_memory=False)

# %% [markdown]
# # Add Area Data to listings dataframe

# %%
# Assuming both DataFrames have a 'zipcode' column to align on
listings = listings.merge(area[['zipcode', 'metro', 'county']], on='zipcode', how='left')
listings
# Out:
#             zipID     city state              streetAddress  zipcode  \
# 0       351078673  Huffman    TX  1647 Plan, Woodland Lakes  77336.0
# 1       351078673  Huffman    TX  1647 Plan, Woodland Lakes  77336.0
# 2        28020741  Houston    TX        10407 Royal Oaks Dr  77016.0
# 3        28020741  Houston    TX        10407 Royal Oaks Dr  77016.0
# 4        28020741  Houston    TX        10407 Royal Oaks Dr  77016.0
# ...           ...      ...   ...                        ...      ...
# 33836  2060332592  Houston    TX          2915 Newington Ln  77047.0
# 33837    28094072  Houston    TX           11011 Carlton Dr  77047.0
# 33838    28094072  Houston    TX           11011 Carlton Dr  77047.0
# 33839    28094072  Houston    TX           11011 Carlton Dr  77047.0
# 33840    28094072  Houston    TX           11011 Carlton Dr  77047.0
#
#         latitude  longitude  beds  baths       homeType  ...   builderName  \
# 0      30.030027  95.112015   3.0    3.0  SINGLE_FAMILY  ...  Cyrene Homes
# 1      30.030027  95.112015   3.0    3.0  SINGLE_FAMILY  ...  Cyrene Homes
# 2      29.862747  95.302640   3.0    1.0  SINGLE_FAMILY  ...           NaN
# 3      29.862747  95.302640   3.0    1.0  SINGLE_FAMILY  ...           NaN
# 4      29.862747  95.302640   3.0    1.0  SINGLE_FAMILY  ...           NaN
# ...          ...        ...   ...    ...            ...  ...           ...
# 33836  29.620047  95.376785   3.0    2.0  SINGLE_FAMILY  ...           NaN
# 33837  29.639648  95.366730   2.0    2.0  SINGLE_FAMILY  ...           NaN
# 33838  29.639648  95.366730   2.0    2.0  SINGLE_FAMILY  ...           NaN
# 33839  29.639648  95.366730   2.0    2.0  SINGLE_FAMILY  ...           NaN
# 33840  29.639648  95.366730   2.0    2.0  SINGLE_FAMILY  ...           NaN
#
#        newConstructionType  isPremierBuilder  is_newHome  \
# 0             BUILDER_PLAN              True        True
# 1             BUILDER_PLAN              True        True
# 2                      NaN             False         NaN
# 3                      NaN             False         NaN
# 4                      NaN             False         NaN
# ...                    ...               ...         ...
# 33836                  NaN             False         NaN
# 33837                  NaN             False         NaN
# 33838                  NaN             False         NaN
# 33839                  NaN             False         NaN
# 33840                  NaN             False         NaN
#
#                      flexFieldText  flexFieldType  \
# 0                     Lake breezes    homeInsight
# 1                     Lake breezes    homeInsight
# 2                         Showcase       showcase
# 3                         Showcase       showcase
# 4                         Showcase       showcase
# ...                            ...            ...
# 33836              Modern elegance    homeInsight
# 33837  Price cut: $10,000 (Oct 02)       priceCut
# 33838  Price cut: $10,000 (Oct 02)       priceCut
# 33839  Price cut: $10,000 (Oct 02)       priceCut
# 33840  Price cut: $10,000 (Oct 02)       priceCut
#
#                                                      url  \
# 0      https://www.zillow.com/community/woodland-lake...
# 1      https://www.zillow.com/community/woodland-lake...
# 2      https://www.zillow.com/homedetails/10407-Royal...
# 3      https://www.zillow.com/homedetails/10407-Royal...
# 4      https://www.zillow.com/homedetails/10407-Royal...
# ...                                                  ...
# 33836  https://www.zillow.com/homedetails/2915-Newing...
# 33837  https://www.zillow.com/homedetails/11011-Carlt...
# 33838  https://www.zillow.com/homedetails/11011-Carlt...
# 33839  https://www.zillow.com/homedetails/11011-Carlt...
# 33840  https://www.zillow.com/homedetails/11011-Carlt...
#
#                                                   webURL  \
# 0      1647-Plan,-Woodland-Lakes-Huffman-TX-77336.0/3...
# 1      1647-Plan,-Woodland-Lakes-Huffman-TX-77336.0/3...
# 2      10407-Royal-Oaks-Dr-Houston-TX-77016.0/2802074...
# 3      10407-Royal-Oaks-Dr-Houston-TX-77016.0/2802074...
# 4      10407-Royal-Oaks-Dr-Houston-TX-77016.0/2802074...
# ...                                                  ...
# 33836  2915-Newington-Ln-Houston-TX-77047.0/206033259...
# 33837  11011-Carlton-Dr-Houston-TX-77047.0/28094072_z...
# 33838  11011-Carlton-Dr-Houston-TX-77047.0/28094072_z...
# 33839  11011-Carlton-Dr-Houston-TX-77047.0/28094072_z...
# 33840  11011-Carlton-Dr-Houston-TX-77047.0/28094072_z...
#
#                                   metro    county
# 0      Houston-The Woodlands-Sugar Land    Harris
# 1                                   NaN    Harris
# 2      Houston-The Woodlands-Sugar Land    Harris
# 3                                   NaN    Harris
# 4                                   NaN    Harris
# ...                                 ...       ...
# 33836                               NaN    Harris
# 33837  Houston-The Woodlands-Sugar Land    Harris
# 33838  Houston-The Woodlands-Sugar Land  Brazoria
# 33839                               NaN    Harris
# 33840                               NaN    Harris
#
# [33841 rows x 35 columns]

# %% [markdown]
# ## Property Specific Calculations

# %%
# Calculate Price per Square Foot
# Calculate Price per Square Foot and round to 2 decimal places
listings['pricePerSqft'] = (listings['price'] / listings['sqft']).round(2)

# Calculate Beds to Baths Ratio, round to 1 decimal place
listings['bedToBathRatio'] = (np.where(listings['baths'] != 0, (listings['beds'] / listings['baths']).round(1), np.nan)).round(1)
#listings

# %% [markdown]
# # Add Census Data to listings dataframe

# %%
# Assuming both DataFrames have a 'zipcode' column to align on
listings = listings.merge(census[['zipcode', 'medianIncome']], on='zipcode', how='left')
#listings

# %%
# Individual Monetary Estiamtions

# %%
# Assume a 20% Down Payment of Listing Price
listings['downPayment'] = (listings['price']*.20).round(0)

# %%
# Reoder columns

# %%
column_order = [
    # Location Information
    'zipID',
    'city',
    'state',
    'streetAddress',
    'zipcode',
    'latitude',
    'longitude',
    'metro',
    'county',

    # Property Details
    'homeType',
    'beds',
    'baths',
    'sqft',
    'acreage',
    'newConstructionType',
    'is_newHome',

    # Pricing Information
    'price',
    'priceChange',
    'zestimate',
    'rentZestimate',
    'taxAssessedValue',
    'pricePerSqft',
    'bedToBathRatio',

    # Listing Information
    'listingType',
    'daysOnZillow',
    'statusText',
    'statusType',
    'isFeaturedListing',
    'isShowcaseListing',
    'brokerName',
    'builderName',
    'isPremierBuilder',
    'flexFieldText',
    'flexFieldType',

    # Date Information
    'datePriceChanged',

    # Monetary Estimations
    'downPayment',
    
    # Income Information
    'medianIncome',

]

# Reorder the DataFrame columns
listings = listings[column_order]

# %%
listings
# Out:
#             zipID     city state              streetAddress  zipcode  \
# 0       351078673  Huffman    TX  1647 Plan, Woodland Lakes  77336.0
# 1       351078673  Huffman    TX  1647 Plan, Woodland Lakes  77336.0
# 2        28020741  Houston    TX        10407 Royal Oaks Dr  77016.0
# 3        28020741  Houston    TX        10407 Royal Oaks Dr  77016.0
# 4        28020741  Houston    TX        10407 Royal Oaks Dr  77016.0
# ...           ...      ...   ...                        ...      ...
# 33836  2060332592  Houston    TX          2915 Newington Ln  77047.0
# 33837    28094072  Houston    TX           11011 Carlton Dr  77047.0
# 33838    28094072  Houston    TX           11011 Carlton Dr  77047.0
# 33839    28094072  Houston    TX           11011 Carlton Dr  77047.0
# 33840    28094072  Houston    TX           11011 Carlton Dr  77047.0
#
#         latitude  longitude                             metro    county  \
# 0      30.030027  95.112015  Houston-The Woodlands-Sugar Land    Harris
# 1      30.030027  95.112015                               NaN    Harris
# 2      29.862747  95.302640  Houston-The Woodlands-Sugar Land    Harris
# 3      29.862747  95.302640                               NaN    Harris
# 4      29.862747  95.302640                               NaN    Harris
# ...          ...        ...                               ...       ...
# 33836  29.620047  95.376785                               NaN    Harris
# 33837  29.639648  95.366730  Houston-The Woodlands-Sugar Land    Harris
# 33838  29.639648  95.366730  Houston-The Woodlands-Sugar Land  Brazoria
# 33839  29.639648  95.366730                               NaN    Harris
# 33840  29.639648  95.366730                               NaN    Harris
#
#             homeType  ...  isFeaturedListing  isShowcaseListing  \
# 0      SINGLE_FAMILY  ...              False              False
# 1      SINGLE_FAMILY  ...              False              False
# 2      SINGLE_FAMILY  ...              False               True
# 3      SINGLE_FAMILY  ...              False               True
# 4      SINGLE_FAMILY  ...              False               True
# ...              ...  ...                ...                ...
# 33836  SINGLE_FAMILY  ...              False              False
# 33837  SINGLE_FAMILY  ...              False              False
# 33838  SINGLE_FAMILY  ...              False              False
# 33839  SINGLE_FAMILY  ...              False              False
# 33840  SINGLE_FAMILY  ...              False              False
#
#                        brokerName   builderName isPremierBuilder  \
# 0                             NaN  Cyrene Homes             True
# 1                             NaN  Cyrene Homes             True
# 2        Corcoran Prestige Realty           NaN            False
# 3        Corcoran Prestige Realty           NaN            False
# 4        Corcoran Prestige Realty           NaN            False
# ...                           ...           ...              ...
# 33836       Collective Realty Co.           NaN            False
# 33837  G. K. Coleman & Son Realty           NaN            False
# 33838  G. K. Coleman & Son Realty           NaN            False
# 33839  G. K. Coleman & Son Realty           NaN            False
# 33840  G. K. Coleman & Son Realty           NaN            False
#
#                      flexFieldText  flexFieldType  datePriceChanged  \
# 0                     Lake breezes    homeInsight               NaN
# 1                     Lake breezes    homeInsight               NaN
# 2                         Showcase       showcase               NaN
# 3                         Showcase       showcase               NaN
# 4                         Showcase       showcase               NaN
# ...                            ...            ...               ...
# 33836              Modern elegance    homeInsight               NaN
# 33837  Price cut: $10,000 (Oct 02)       priceCut        2024-10-02
# 33838  Price cut: $10,000 (Oct 02)       priceCut        2024-10-02
# 33839  Price cut: $10,000 (Oct 02)       priceCut        2024-10-02
# 33840  Price cut: $10,000 (Oct 02)       priceCut        2024-10-02
#
#        downPayment  medianIncome
# 0          53798.0         82105
# 1          53798.0         82105
# 2          24000.0         42186
# 3          24000.0         42186
# 4          24000.0         42186
# ...            ...           ...
# 33836      69000.0         70666
# 33837      36000.0         70666
# 33838      36000.0         70666
# 33839      36000.0         70666
# 33840      36000.0         70666
#
# [33841 rows x 37 columns]

# %% [markdown]
# # Save File

# %%
# Define the file path
csv_file_path = os.path.join(master_dir, master_file)
listings.to_csv(csv_file_path, index=False)
